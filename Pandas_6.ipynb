# %% [markdown]
# ### Read html, pivot table, save file

# %%
import pandas as pd

# %%
df_wage = pd.read_csv("Data/Minimum Wage Data.csv", encoding = "latin")
df_wage
# Out:
#       Year          State           Table_Data Footnote  High.Value  \
# 0     1968        Alabama                  ...      NaN     0.00000
# 1     1968         Alaska                 2.10      NaN     2.10000
# 2     1968        Arizona  18.72 - 26.40/wk(b)      (b)     0.66000
# 3     1968       Arkansas          1.25/day(b)      (b)     0.15625
# 4     1968     California              1.65(b)      (b)     1.65000
# ...    ...            ...                  ...      ...         ...
# 2745  2017       Virginia              7.25[c]      [c]     7.25000
# 2746  2017     Washington                11.00      NaN    11.00000
# 2747  2017  West Virginia                 8.75      NaN     8.75000
# 2748  2017      Wisconsin                 7.25      NaN     7.25000
# 2749  2017        Wyoming                 5.15      NaN     5.15000
#
#       Low.Value  CPI.Average  High.2018  Low.2018
# 0       0.00000    34.783333       0.00      0.00
# ...

# %%
gb = df_wage.groupby("State")
gb.get_group("California").set_index("Year").head()
# Out:
#            State Table_Data Footnote  High.Value  Low.Value  CPI.Average  \
# Year
# 1968  California    1.65(b)      (b)        1.65       1.65    34.783333
# 1969  California    1.65(b)      (b)        1.65       1.65    36.683333
# 1970  California    1.65(b)      (b)        1.65       1.65    38.825000
# 1971  California    1.65(b)      (b)        1.65       1.65    40.491667
# 1972  California    1.65(b)      (b)        1.65       1.65    41.816667
#
#       High.2018  Low.2018
# Year
# 1968      11.88     11.88
# 1969      11.26     11.26
# 1970      10.64     10.64
# 1971      10.20     10.20
# 1972       9.88      9.88

# %%
pd.pivot_table(df_wage, values="Low.2018", index = "Year", columns = "State").head()
# Out:
# State  Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968       0.0   15.12     3.37      1.12       11.88      7.20        10.08
# 1969       0.0   14.33     3.19      1.07       11.26      6.83         9.56
# 1970       0.0   13.54     3.02      7.09       10.64      6.45        10.32
# 1971       0.0   12.99     2.89      6.80       10.20      6.18         9.89
# 1972       0.0   12.57     2.80      7.19        9.88      5.99        11.08
#
# State  Delaware  District of Columbia  Federal (FLSA)  ...  Tennessee  Texas  \
# Year                                                   ...
# 1968       9.00                  9.00            8.28  ...        0.0   0.00
# 1969       8.53                  8.53            7.85  ...        0.0   0.00
# 1970       8.06                 10.32            8.38  ...        0.0   0.00
# 1971       7.73                  9.89            8.04  ...        0.0   0.00
# ...

# %%
# get table from a web page

dfs = pd.read_html("https://yucex.com/turkiye-81-il-sehir-listesi.html")

for df in dfs:
    print(df)
# Out:
#         0               1                 2
# 0   Plaka    İl/Şehir Adı               NaN
# 1   Plaka    İl/Şehir Adı  TelefonAlan Kodu
# 2       1           Adana               322
# 3       2        Adıyaman               416
# 4       3  Afyonkarahisar               272
# ..    ...             ...               ...
# 78     77          Yalova               226
# 79     78         Karabük               370
# 80     79           Kilis               348
# 81     80        Osmaniye               328
# 82     81           Düzce               380
#
# [83 rows x 3 columns]

# %%
df =df[1:]
df.head()
# Out:
#        0               1                 2
# 1  Plaka    İl/Şehir Adı  TelefonAlan Kodu
# 2      1           Adana               322
# 3      2        Adıyaman               416
# 4      3  Afyonkarahisar               272
# 5      4            Ağrı               472

# %%
df.columns = ["Plaka", "İl/Şehir Adı", "TelefonAlan Kodu"]
df = df[1:]
df.set_index("Plaka", inplace=True)
df
# Out:
#          İl/Şehir Adı TelefonAlan Kodu
# Plaka
# 1               Adana              322
# 2            Adıyaman              416
# 3      Afyonkarahisar              272
# 4                Ağrı              472
# 5              Amasya              358
# ...               ...              ...
# 77             Yalova              226
# 78            Karabük              370
# 79              Kilis              348
# 80           Osmaniye              328
# 81              Düzce              380
#
# [81 rows x 2 columns]

# %%
# save the dataframe as a csv

df.to_csv("Data/sehir.csv")

# %%
sehir = pd.read_csv("Data/sehir.csv")
sehir
# Out:
#     Plaka    İl/Şehir Adı  TelefonAlan Kodu
# 0       1           Adana               322
# 1       2        Adıyaman               416
# 2       3  Afyonkarahisar               272
# 3       4            Ağrı               472
# 4       5          Amasya               358
# ..    ...             ...               ...
# 76     77          Yalova               226
# 77     78         Karabük               370
# 78     79           Kilis               348
# 79     80        Osmaniye               328
# 80     81           Düzce               380
#
# [81 rows x 3 columns]
