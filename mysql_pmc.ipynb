# %%
import pandas as pd

from sqlalchemy import create_engine

# %%
hostname = "192.168.0.11"
username = "root"
password = "SqlAdmin"
database = "pmc_db"
# Open database connection
engine = create_engine('mysql+mysqlconnector://root:1234@localhost:3306/pmc_db', echo=False)

# %%
engine
# Out:
# Engine(mysql+mysqlconnector://root:***@localhost:3306/pmc_db)

# %%
df_1 = pd.read_excel("D:\DATASCIENCE\Project\PMC_backup\data\ProjectPlanData.xlsx")
df_1
# Out:
#       RowID  ParentRowID  TaskID  ParentTaskID TeamName         TaskName  \
# 0         1          NaN   51541           NaN       HR         Task 651
# 1        15          5.0   51548       51543.0       HR  Summary Task141
# 2        30         15.0   51556       51548.0       IT  Summary Task157
# 3       130        110.0   51590       51580.0       IT     Milestone133
# 4       140        110.0   51595       51580.0       IT         Task 762
# ...     ...          ...     ...           ...      ...              ...
# 1334   1116       1090.0   52821       52808.0       IT         Task 810
# 1335   1150          3.0   52828       52433.0       HR         Task 231
# 1336   1220       1210.0   52853       52848.0       IT          Task135
# 1337   1234       1210.0   52860       52848.0       HR           Task40
# 1338   1266       1210.0   52876       52848.0       HR         Task 133
#
#           TaskType TaskScheduleType  Duration PlannedStartDate  ...  \
# ...

# %%
# df_1.to_sql('projectplandata', con=engine, if_exists='replace', index = False)

# %%
df_2 = pd.read_excel("D:\DATASCIENCE\Project\PMC_backup\data\Dependencies.xlsx")
df_2
# Out:
#               TaskName      DependentOn PlannedStartDate  StartDate  \
# 0            Task 6510         Task 651       2020-05-13 2020-05-13
# 1            Task 6511         Task 651       2020-04-12 2020-04-12
# 2     Summary Task1410  Summary Task141       2020-04-19 2020-04-19
# 3     Summary Task1411  Summary Task141       2020-06-07 2020-06-07
# 4     Summary Task1412  Summary Task141       2020-06-05 2020-06-05
# ...                ...              ...              ...        ...
# 6102          Task4012           Task40       2021-05-12 2021-05-12
# 6103         Task 1330         Task 133       2021-04-23 2021-04-23
# 6104         Task 1331         Task 133       2021-04-08 2021-04-08
# 6105         Task 1332         Task 133       2021-06-16 2021-06-16
# 6106         Task 1333         Task 133       2021-05-27 2021-05-27
#
#         DueDate PlannedDueDate TaskStatus  PercentComplete TaskPriority  \
# 0    2020-05-27     2020-05-27        New               20         High
# ...

# %%
df_2.to_sql('dependencies', con=engine, if_exists='replace', index = False)

# %%
df_3 = pd.read_excel("D:\\DATASCIENCE\\Project\\PMC_backup\\data\\Users.xlsx")
df_3
# Out:
#     UserId      FullName Password First_Name  Last_Name              Name
# 0        1      sgupta01  chatbot     Saresh      Gupta      Saresh Gupta
# 1        2    gpushkin01  chatbot     George    Pushkin    George Pushkin
# 2        3       fcook01  chatbot      Frank       Cook        Frank Cook
# 3        4       pkhan01  chatbot    Parmesh       Khan      Parmesh Khan
# 4        5       mreed01  chatbot    Matthew       Reed      Matthew Reed
# 5        6      kverma01  chatbot     Keshav      Verma      Keshav Verma
# 6        7      kowens01  chatbot       Karl      Owens        Karl Owens
# 7        8      kowens02  chatbot       Karl      Owens        Karl Owens
# 8        9   rmccarter01  chatbot    Richard   McCarter  Richard McCarter
# 9       10  asabapathi01  chatbot      Aahan  Sabapathi   Aahan Sabapathi
# 10      11       sboyd01  chatbot       Sara       Boyd         Sara Boyd
# 11      12      dperez01  chatbot      Diana      Perez       Diana Perez
# ...

# %%
df_3.to_sql('users', con=engine, if_exists='replace', index = False)

# %%
df = pd.read_csv("./PMC/data/external_data/senol.csv")
df
# Out:
#       RowID  ParentRowID  TaskID  ParentTaskID TeamName         TaskName  \
# 0         1          NaN   34041           NaN       IT    Summary Task1
# 1         2          NaN   34042           NaN       HR       Milestone1
# 2         5          1.0   34043       34041.0       IT            Task3
# 3         6          2.0   34044       34042.0       HR  Summary Task126
# 4         9          5.0   34045       34043.0       IT     Milestone161
# ...     ...          ...     ...           ...      ...              ...
# 1334   1264       1210.0   35375       35348.0       HR         Task 809
# 1335   1266       1210.0   35376       35348.0       HR         Task 810
# 1336   1268       1210.0   35377       35348.0       HR         Task 811
# 1337   1270       1210.0   35378       35348.0       IT           Parent
# 1338   1272       1210.0   35379       35348.0       HR         Task 612
#
#           TaskType TaskScheduleType  Duration PlannedStartDate  ...  \
# ...

# %%
# df.to_sql('ProjectPlanData', con=engine, if_exists='replace', index = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:1333: UserWarning: The provided table name 'ProjectPlanData' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
query = """SELECT * FROM ProjectPlanData;"""

df_2 = pd.read_sql(query, con=engine)
df_2
# Out:
#       RowID  ParentRowID  TaskID  ParentTaskID TeamName         TaskName  \
# 0         1          NaN   34041           NaN       IT    Summary Task1
# 1         2          NaN   34042           NaN       HR       Milestone1
# 2         5          1.0   34043       34041.0       IT            Task3
# 3         6          2.0   34044       34042.0       HR  Summary Task126
# 4         9          5.0   34045       34043.0       IT     Milestone161
# ...     ...          ...     ...           ...      ...              ...
# 1334   1264       1210.0   35375       35348.0       HR         Task 809
# 1335   1266       1210.0   35376       35348.0       HR         Task 810
# 1336   1268       1210.0   35377       35348.0       HR         Task 811
# 1337   1270       1210.0   35378       35348.0       IT           Parent
# 1338   1272       1210.0   35379       35348.0       HR         Task 612
#
#           TaskType TaskScheduleType  Duration PlannedStartDate  ...  \
# ...

# %%
df_1.TaskName.nunique()
# Out:
# 709

# %%
a = "Task 18"
sql = """SELECT StartDate, DueDate FROM ProjectPlanData 
                        WHERE TaskName = '{}'""".format(a)

data = pd.read_sql(sql,engine)

# %%
len(data)
# Out:
# 1

# %%
d = data

# %%
d
# Out:
#    StartDate    DueDate
# 0 2020-11-12 2020-11-26

# %%
bdays_between = pd.bdate_range(d.StartDate[0], d.DueDate[0])

# %%
len(bdays_between)
# Out:
# 11

# %%
data = pd.read_sql(sql, connSqlServer, parse_dates=["StartDate", "DueDate"])
            
bdays_between = pd.bdate_range(start_date, end_date)

# %%
query = """SELECT * FROM ProjectPlanData;"""

# %%
cursor.execute(query)

# %%
for c in cursor:
    print(c)

# %%
# Open database connection
engine_ex = create_engine('mysql+mysqlconnector://root:1234@localhost:3306/exercise', echo=False)

# %%
connection = engine_ex.raw_connection()
cursor = connection.cursor()

# %%
Id=4
name= "Qwe"
age=12

# %%
cursor.execute("INSERT INTO employees ([Id], [name], [age]) values (?,?,?,?,?)", Id, name, age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-6bd80029cd72> in <module>
# ----> 1 cursor.execute("INSERT INTO employees ([Id], [name], [age]) values (?,?,?,?,?)", Id, name, age)
#
# TypeError: execute() takes from 2 to 4 positional arguments but 5 were given

# %%
cursor.close()

    connection.commit()

# %%
connection.commit()

# %%
connection.close()

# %%
query = """SELECT * FROM employees;"""

# %%
data = pd.read_sql(query,engine_ex)

# %%
data
# Out:
#    id    name  age
# 0   1     Ali   10
# 1   2  Behcet   15
# 2   3   Cemal   20

# %%
query = """SELECT * FROM chat_dummy_main;"""

df_1 = pd.read_sql(query, con=engine)
df_1
# Out:
#       RowID  ParentRowID  TaskID  ParentTaskID TeamName         TaskName  \
# 0         1          NaN   51541           NaN       HR         Task 651
# 1        15          5.0   51548       51543.0       HR  Summary Task141
# 2        30         15.0   51556       51548.0       IT  Summary Task157
# 3       130        110.0   51590       51580.0       IT     Milestone133
# 4       140        110.0   51595       51580.0       IT         Task 762
# ...     ...          ...     ...           ...      ...              ...
# 1334   1116       1090.0   52821       52808.0       IT         Task 810
# 1335   1150          3.0   52828       52433.0       HR         Task 231
# 1336   1220       1210.0   52853       52848.0       IT          Task135
# 1337   1234       1210.0   52860       52848.0       HR           Task40
# 1338   1266       1210.0   52876       52848.0       HR         Task 133
#
#           TaskType TaskScheduleType  Duration PlannedStartDate  ...  \
# ...

# %%
query = """SELECT * FROM chat_dummy_main;"""

df_1 = pd.read_sql(query, con=engine)
df_1

# %%
from datetime import datetime, date
from dateutil.relativedelta import relativedelta

# %%
userid=2

# %%
today = datetime.now().date()
# Out:
# datetime.date(2021, 1, 20)

# %%
from pandas.tseries.offsets import BDay

# %%
end_date = pd.to_datetime(today+BDay(1)).date()
end_date
# Out:
# datetime.date(2021, 1, 18)

# %%
limit=70

# %%
sql = """SELECT TaskName, TaskID, StartDate, DueDate, TaskPriority, PercentComplete 
                FROM chat_dummy_main 
                WHERE UserId = '{}' AND '{}'>= DueDate AND DueDate >= '{}' AND PercentComplete< '{}'
                """.format(userid, end_date, today, limit)

# %%
df_11 = pd.read_sql(sql, con=engine)
df_11

# %%
today = datetime(2021, 1, 21)

# %%
end_date = pd.to_datetime(today+BDay(10)).date()

# %%
sql = """SELECT TaskName, TaskID, StartDate, DueDate, TaskPriority, PercentComplete 
                FROM chat_dummy_main 
                WHERE UserId = '{}' AND '{}'>= DueDate AND DueDate >= '{}' AND PercentComplete< '{}'
                """.format(userid, end_date, today, limit)

# %%
df_11 = pd.read_sql(sql, con=engine)
df_11
# Out:
#    TaskName  TaskID  StartDate    DueDate TaskPriority  PercentComplete
# 0  Task 653   51929 2021-01-15 2021-01-29          Low               54

# %%
df_11.shape
# Out:
# (0, 6)

# %%
print(df_11)
# Out:
#    TaskName  TaskID  StartDate    DueDate TaskPriority  PercentComplete
# 0  Task 653   51929 2021-01-15 2021-01-29          Low               54

# %%
query = """SELECT * FROM chat_dummy_dep;"""

df_2 = pd.read_sql(query, con=engine)
df_2
# Out:
#               TaskName      DependentOn PlannedStartDate  StartDate  \
# 0            Task 6510         Task 651       2020-05-13 2020-05-13
# 1            Task 6511         Task 651       2020-04-12 2020-04-12
# 2     Summary Task1410  Summary Task141       2020-04-19 2020-04-19
# 3     Summary Task1411  Summary Task141       2020-06-07 2020-06-07
# 4     Summary Task1412  Summary Task141       2020-06-05 2020-06-05
# ...                ...              ...              ...        ...
# 6102          Task4012           Task40       2021-05-12 2021-05-12
# 6103         Task 1330         Task 133       2021-04-23 2021-04-23
# 6104         Task 1331         Task 133       2021-04-08 2021-04-08
# 6105         Task 1332         Task 133       2021-06-16 2021-06-16
# 6106         Task 1333         Task 133       2021-05-27 2021-05-27
#
#         DueDate PlannedDueDate TaskStatus  PercentComplete TaskPriority  \
# 0    2020-05-27     2020-05-27        New               20         High
# ...

# %%
query = """SELECT * FROM chat_dummy_users;"""

df_3 = pd.read_sql(query, con=engine)
df_3
# Out:
#     UserId      FullName Password First_Name  Last_Name              Name
# 0        1      sgupta01  chatbot     Saresh      Gupta      Saresh Gupta
# 1        2    gpushkin01  chatbot     George    Pushkin    George Pushkin
# 2        3       fcook01  chatbot      Frank       Cook        Frank Cook
# 3        4       pkhan01  chatbot    Parmesh       Khan      Parmesh Khan
# 4        5       mreed01  chatbot    Matthew       Reed      Matthew Reed
# 5        6      kverma01  chatbot     Keshav      Verma      Keshav Verma
# 6        7      kowens01  chatbot       Karl      Owens        Karl Owens
# 7        8      kowens02  chatbot       Karl      Owens        Karl Owens
# 8        9   rmccarter01  chatbot    Richard   McCarter  Richard McCarter
# 9       10  asabapathi01  chatbot      Aahan  Sabapathi   Aahan Sabapathi
# 10      11       sboyd01  chatbot       Sara       Boyd         Sara Boyd
# 11      12      dperez01  chatbot      Diana      Perez       Diana Perez
# ...

# %%
# Out:
#               TaskName      DependentOn PlannedStartDate  StartDate  \
# 0            Task 6510         Task 651       2020-05-13 2020-05-13
# 1            Task 6511         Task 651       2020-04-12 2020-04-12
# 2     Summary Task1410  Summary Task141       2020-04-19 2020-04-19
# 3     Summary Task1411  Summary Task141       2020-06-07 2020-06-07
# 4     Summary Task1412  Summary Task141       2020-06-05 2020-06-05
# ...                ...              ...              ...        ...
# 6102          Task4012           Task40       2021-05-12 2021-05-12
# 6103         Task 1330         Task 133       2021-04-23 2021-04-23
# 6104         Task 1331         Task 133       2021-04-08 2021-04-08
# 6105         Task 1332         Task 133       2021-06-16 2021-06-16
# 6106         Task 1333         Task 133       2021-05-27 2021-05-27
#
#         DueDate PlannedDueDate TaskStatus  PercentComplete TaskPriority  \
# 0    2020-05-27     2020-05-27        New               20         High
# ...

# %%
# Open database connection
engine = create_engine('mysql+mysqlconnector://goldcot:password123@35.223.204.114:3306/pmc_db', echo=False)

# %%
query = """SELECT * FROM Deneme;"""

df = pd.read_sql(query, con=engine)
df
# Out:
#    Alpha  Beta
# 0      1     6
# 1      2     7
# 2      3     8
# 3      4     9
# 4      5    10

# %%
df_3.to_sql('chat_dummy_users', con=engine, if_exists='replace', index = False)

# %%
df_1
# Out:
#       RowID  ParentRowID  TaskID  ParentTaskID TeamName         TaskName  \
# 0         1          NaN   51541           NaN       HR         Task 651
# 1        15          5.0   51548       51543.0       HR  Summary Task141
# 2        30         15.0   51556       51548.0       IT  Summary Task157
# 3       130        110.0   51590       51580.0       IT     Milestone133
# 4       140        110.0   51595       51580.0       IT         Task 762
# ...     ...          ...     ...           ...      ...              ...
# 1334   1116       1090.0   52821       52808.0       IT         Task 810
# 1335   1150          3.0   52828       52433.0       HR         Task 231
# 1336   1220       1210.0   52853       52848.0       IT          Task135
# 1337   1234       1210.0   52860       52848.0       HR           Task40
# 1338   1266       1210.0   52876       52848.0       HR         Task 133
#
#           TaskType TaskScheduleType  Duration PlannedStartDate  ...  \
# ...

# %%
alist= list(range(4,161,4))
alist
# Out:
# [4,
#  8,
#  12,
#  16,
#  20,
#  24,
#  28,
#  32,
#  36,
#  40,
#  44,
#  48,
#  52,
#  56,
#  60,
#  64,
#  68,
#  72,
#  76,
#  80,
#  84,
#  88,
#  92,
#  96,
#  100,
#  104,
#  108,
#  112,
#  116,
#  120,
#  124,
#  128,
#  132,
#  136,
#  140,
#  144,
#  148,
#  152,
#  156,
#  160]

# %%
import numpy as np

# %%
df_1["EffortHours"] = np.random.choice(alist,1339)

# %%
df_1
# Out:
#       RowID  ParentRowID  TaskID  ParentTaskID TeamName         TaskName  \
# 0         1          NaN   51541           NaN       HR         Task 651
# 1        15          5.0   51548       51543.0       HR  Summary Task141
# 2        30         15.0   51556       51548.0       IT  Summary Task157
# 3       130        110.0   51590       51580.0       IT     Milestone133
# 4       140        110.0   51595       51580.0       IT         Task 762
# ...     ...          ...     ...           ...      ...              ...
# 1334   1116       1090.0   52821       52808.0       IT         Task 810
# 1335   1150          3.0   52828       52433.0       HR         Task 231
# 1336   1220       1210.0   52853       52848.0       IT          Task135
# 1337   1234       1210.0   52860       52848.0       HR           Task40
# 1338   1266       1210.0   52876       52848.0       HR         Task 133
#
#           TaskType TaskScheduleType  Duration PlannedStartDate  ...  \
# ...

# %%
# df_1.to_sql('chat_dummy_main_copy', con=engine, if_exists='replace', index = False)

# %%
# data.to_sql('task', con=engine, if_exists='replace', index = False)

# %%
list(df_1.columns)
# Out:
# ['RowID',
#  'ParentRowID',
#  'TaskID',
#  'ParentTaskID',
#  'TeamName',
#  'TaskName',
#  'TaskType',
#  'TaskScheduleType',
#  'Duration',
#  'PlannedStartDate',
#  'StartDate',
#  'PlannedDueDate',
#  'DueDate',
#  'Owners',
#  'TaskStatus',
#  'PercentComplete',
#  'TaskPriority',
#  'TaskSeverity',
#  'NodeLevel',
#  'Node',
#  'TaskUID',
#  'UserId',
#  'FullName',
#  'Password',
#  'First_Name',
#  'Last_Name',
#  'EffortHours']

# %%
df_1.TaskSeverity.unique()
# Out:
# array(['Low', 'High', 'Medium'], dtype=object)

# %%
a=["quit"]
ls = [1,2,3]

for l in ls:
    a.insert(0, l)

# %%
a
# Out:
# [3, 2, 1, 'quit']

# %%
task_name = "Task 64"
sql = """SELECT * FROM chat_dummy_main_copy 
                        WHERE TaskName = '{}' """.format(task_name)

# %%
data = pd.read_sql(sql, con=engine)
data.iloc[0].TaskStatus
# Out:
# 'At Risk'

# %%
df_1.TaskName.nunique()
# Out:
# 709

# %%
feature="TaskName"
df_1[feature]
# Out:
# 0              Task 651
# 1       Summary Task141
# 2       Summary Task157
# 3          Milestone133
# 4              Task 762
#              ...
# 1334           Task 810
# 1335           Task 231
# 1336            Task135
# 1337             Task40
# 1338           Task 133
# Name: TaskName, Length: 1339, dtype: object

# %%
df_1
# Out:
#       RowID  ParentRowID  TaskID  ParentTaskID TeamName         TaskName  \
# 0         1          NaN   51541           NaN       HR         Task 651
# 1        15          5.0   51548       51543.0       HR  Summary Task141
# 2        30         15.0   51556       51548.0       IT  Summary Task157
# 3       130        110.0   51590       51580.0       IT     Milestone133
# 4       140        110.0   51595       51580.0       IT         Task 762
# ...     ...          ...     ...           ...      ...              ...
# 1334   1116       1090.0   52821       52808.0       IT         Task 810
# 1335   1150          3.0   52828       52433.0       HR         Task 231
# 1336   1220       1210.0   52853       52848.0       IT          Task135
# 1337   1234       1210.0   52860       52848.0       HR           Task40
# 1338   1266       1210.0   52876       52848.0       HR         Task 133
#
#           TaskType TaskScheduleType  Duration PlannedStartDate  ...  \
# ...

# %%
a =df_1.iloc[0].StartDate.date()

# %%
a
# Out:
# datetime.date(2020, 12, 2)

# %%
a.strftime("%d %b %Y")
# Out:
# '02 Dec 2020'

# %%
a =[1,2,3]
b = [1,2]

# %%
a.remove([1,2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-7b70e71a5db0> in <module>
# ----> 1 a.remove([1,2])
#
# ValueError: list.remove(x): x not in list

# %%
a
# Out:
# [2, 3]

# %%
def zx(a):
    return a.remove(2)

# %%
a=[1,2,3,4]

# %%
zx(a)

# %%
task_name= "Task 64"
sql = """SELECT Owners FROM chat_dummy_main_copy 
                        WHERE TaskName = '{}' """.format(task_name)

owner_data = pd.read_sql(sql, engine)
existing_value = owner_data["Owners"].iloc[0]

# %%
existing_value
# Out:
# 'Sara Boyd'

# %%
engine = create_engine('mysql+mysqlconnector://root:1234@localhost:3306/pmc_db', echo=False)

# %%
from datetime import datetime, date, timedelta
from dateutil import relativedelta, parser
import pandas as pd

# convert datetime and date in order to use available data
# next two variable should be replaced 
now_datetime = datetime.now() - relativedelta.relativedelta(years=1)
now_date = now_datetime.date()

# %%
# ROLES should be replaced with a query result after integration
ROLES = {"business analyst": ["Diana Perez", "Sara Boyd", "Frank Cook"],
    "application architect": ["Karl Owens", "Test User"],
    "qa tester": ["Samir Sljivo", "Varesh Swati"],
    "software developer": ["Parmesh Khan", "George Pushkin", "Richard McCarter"], 
    "devops engineer": ["Matthew Reed", "Saresh Gupta", "Thomas Douglas"],
    "managing director": ["Keshav Verma", "Aahan Sabapathi"]}

# %%
names = ROLES["business analyst"]
df = pd.DataFrame()

for i, name in enumerate(names):
    sql = """SELECT Owners, COUNT(TaskName) as total
                        FROM chat_dummy_main_copy 
                        WHERE DueDate >= '{}' AND Owners = '{}'
                        GROUP BY Owners""".format(now_date, name)
    data = pd.read_sql(sql, engine)
    data['total'][0]
    df.loc[i,'tasks'] = data['total'][0]
    
    df.loc[i,'owner'] = name
df = df.sort_values('tasks')
    
name_1 = '{} - {} tasks'.format(df['owner'][0], int(df['tasks'][0]))
name_2 = '{} - {} tasks'.format(df['owner'][1], int(df['tasks'][1]))

# %%
df = df[df.owner!="Sara Boyd"]

# %%
df
# Out:
#    tasks        owner
# 2   74.0   Frank Cook
# 0   87.0  Diana Perez

# %%
task_name = "Task 64"
sql = """SELECT * FROM chat_dummy_main_copy 
                        WHERE TaskName = '{}' """.format(task_name)

# %%
data = pd.read_sql(sql, con=engine)
data.iloc[0].TaskStatus
# Out:
# 'Active'

# %%
data

# %%
import numpy as np

# %%
str(data["PercentComplete"].iloc[0])
# Out:
# '10'

# %%
str(data["EffortHours"].iloc[0])
# Out:
# '40'

# %%
isinstance(data["PercentComplete"].iloc[0], np.int64)
# Out:
# True

# %%
isnumeric(data["PercentComplete"].iloc[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b8860523b47c> in <module>
# ----> 1 isnumeric(data["PercentComplete"].iloc[0])
#
# NameError: name 'isnumeric' is not defined

# %%
ROLES = {"business analyst": ["Diana Perez", "Sara Boyd", "Frank Cook"],
    "application architect": ["Karl Owens", "Test User"],
    "qa tester": ["Samir Sljivo", "Varesh Swati"],
    "software developer": ["Parmesh Khan", "George Pushkin", "Richard McCarter"], 
    "devops engineer": ["Matthew Reed", "Saresh Gupta", "Thomas Douglas"],
    "managing director": ["Keshav Verma", "Aahan Sabapathi"]}

# %%
from datetime import datetime

dummy_owner = "business analyst"
existing = "Diana Perez"
now_date=datetime.now().date()

# %%
ROLES[dummy_owner]
# Out:
# ['Sara Boyd', 'Frank Cook']

# %%
names

# %%
names = ROLES[dummy_owner].copy()
if existing in  ROLES[dummy_owner]:
    names.remove(existing)

# %%
df = pd.DataFrame()

for i, name in enumerate(names):
    
    sql = """SELECT Owners, COUNT(TaskName) as total
                        FROM chat_dummy_main 
                        WHERE DueDate >= '{}' AND Owners = '{}'
                        GROUP BY Owners""".format(now_date, name)
    data = pd.read_sql(sql, engine)
    print(data)
    data['total'][0]
    df.loc[i,'tasks'] = data['total'][0]
    df.loc[i,'owner'] = name
df = df.sort_values('tasks')
# Out:
#       Owners  total
# 0  Sara Boyd     26
#        Owners  total
# 0  Frank Cook     30

# %%
names= tuple(names)
names
# Out:
# ('Sara Boyd', 'Frank Cook')

# %%
names
# Out:
# ['Sara Boyd', 'Frank Cook']

# %%
    sql = f"""SELECT Owners, COUNT(TaskName) as total
                        FROM chat_dummy_main 
                        WHERE DueDate >= '{now_date}' AND Owners IN {tuple(names)}
                        GROUP BY Owners"""
    data = pd.read_sql(sql, engine)
    data
# Out:
#        Owners  total
# 0  Frank Cook     30
# 1   Sara Boyd     26

# %%
task_name = "Task 64"
sql = """SELECT * FROM chat_dummy_main_copy 
                        WHERE TaskName = '{}' LIMIT 1""".format(task_name)

# %%
data = pd.read_sql(sql, con=engine)
data.TaskID
# Out:
# 0    52214
# Name: TaskID, dtype: int64

# %%
data
# Out:
#    RowID  ParentRowID  TaskID  ParentTaskID TeamName TaskName TaskType  \
# 0    663        607.0   52214       51753.0       HR  Task 64     Task
#
#   TaskScheduleType  Duration PlannedStartDate  ... TaskSeverity NodeLevel  \
# 0             Auto    -351.0       2021-06-21  ...       Medium         4
#
#         Node   TaskUID UserId  FullName Password First_Name  Last_Name  \
# 0  HR.1.2.5.  HR.34973      6  kverma01  chatbot     Keshav      Verma
#
#   EffortHours
# 0          50
#
# [1 rows x 27 columns]

# %%
task_name = "Task 12"
sql = """SELECT * FROM chat_dummy_main_copy 
                        WHERE TaskName = '{}' """.format(task_name)
data = pd.read_sql(sql, con=engine)

# %%
data
# Out:
#    RowID  ParentRowID  TaskID  ParentTaskID TeamName TaskName   TaskType  \
# 0    624        607.0   51761       51753.0       IT  Task 12  Milestone
# 1    922        850.0   51872       51836.0       IT  Task 12       Task
#
#   TaskScheduleType  Duration PlannedStartDate  ... TaskSeverity NodeLevel  \
# 0           Manual      14.0       2021-06-12  ...         High         2
# 1           Manual      14.0       2020-11-21  ...         High         1
#
#           Node   TaskUID UserId  FullName Password First_Name  Last_Name  \
# 0   HR.1.20.8.  HR.35181      7  kowens01  chatbot       Karl      Owens
# 1  IT.1.20.11.  IT.34688     15  vswati01  chatbot     Varesh      Swati
#
#   EffortHours
# 0         140
# 1          92
#
# [2 rows x 27 columns]

# %%
type(a)
# Out:
# int

# %%
b = data.TaskID[0]

# %%
type(b)
# Out:
# numpy.int64

# %%
b = data.TaskName[0]

# %%
b
# Out:
# 'Task 64'

# %%
taskId = "52214"

sql = """SELECT * FROM chat_dummy_main_copy 
                        WHERE TaskID = '{}' """.format(taskId)

data = pd.read_sql(sql, con=engine)
data
# Out:
#    RowID  ParentRowID  TaskID  ParentTaskID TeamName TaskName TaskType  \
# 0    663        607.0   52214       51753.0       HR  Task 64     Task
#
#   TaskScheduleType  Duration PlannedStartDate  ... TaskSeverity NodeLevel  \
# 0             Auto    -351.0       2021-06-21  ...       Medium         4
#
#         Node   TaskUID UserId  FullName Password First_Name  Last_Name  \
# 0  HR.1.2.5.  HR.34973      6  kverma01  chatbot     Keshav      Verma
#
#   EffortHours
# 0          50
#
# [1 rows x 27 columns]

# %%
data.TaskName[0]
# Out:
# 'Task 64'

# %%
from datetime import datetime

# %%
TaskID = 52214

# %%
n = [["StartDate", "11/01/2020", "21 Jan 2021"], ["TaskPriority", "High", "Low"], ["DueDate", "11/01/2020", "21 Feb 2021"], ["TaskName", "qwe", "Task 644"]]

# %%
len(n)
# Out:
# 4

# %%
update_text = ""
edit_text=""

# %%
for el in n:
    if el[0] in ["StartDate", "DueDate"]:
        el[2] = datetime.strptime(el[2], '%d %b %Y')
    update_text += f"{el[0]} = '{el[2]}',"
    
    edit_text += f"{el[0]}, "

# %%
update_text = update_text[:-1]

# %%
update_text
# Out:
# "StartDate = '2021-01-21 00:00:00',TaskPriority = 'Low',DueDate = '2021-02-21 00:00:00',TaskName = 'Task 644'"

# %%
query_text = f""" UPDATE chat_dummy_main_copy SET {update_text} WHERE TaskID = "{TaskID}" """
query_text
# Out:
# ' UPDATE chat_dummy_main_copy SET StartDate = \'2021-01-21 00:00:00\',TaskPriority = \'Low\',DueDate = \'2021-02-21 00:00:00\',TaskName = \'Task 644\' WHERE TaskID = "52214" '

# %%
q = "SELECT TaskID, StartDate, DueDate, TaskName, TaskPriority FROM chat_dummy_main_copy WHERE TaskID = 52214"

# %%
d = pd.read_sql(q, engine)

# %%
d
# Out:
#    TaskID  StartDate    DueDate  TaskName TaskPriority
# 0   52214 2021-01-21 2021-02-21  Task 644          Low

# %%
TaskID = 52214

sql_conn = engine.connect()

sql_conn.execute(query_text)
sql_conn.close()

# %%
edit_text
# Out:
# 'StartDate, TaskPriority, DueDate, TaskName, '

# %%
edit_text[:-2]
# Out:
# 'StartDate, TaskPriority, DueDate, TaskName'

# %%
r= []

# %%
len(r)
# Out:
# 0

# %%
buttons=[{"title": "Task Name", "payload":"TaskName"},
                {"title": "Start Date", "payload":"StartDate"},
                {"title": "Due Date", "payload":"DueDate"},
                {"title": "Owner", "payload":"Owners"},
                {"title": "Quit Form", "payload":"/quit_form"},
                {"title": "More", "payload":"second list"}]

n = [["StartDate", "11/01/2020", "21 Jan 2021"], ["TaskPriority", "High", "Low"], ["DueDate", "11/01/2020", "21 Feb 2021"], ["TaskName", "qwe", "Task 644"]]

# %%
remove_button_list=[]

for item in buttons:
    if any([item['payload'] == el[0] for el in n]):
        
        remove_button_list.append(item)

# %%
remove_button_list
# Out:
# [{'title': 'Task Name', 'payload': 'TaskName'},
#  {'title': 'Start Date', 'payload': 'StartDate'},
#  {'title': 'Due Date', 'payload': 'DueDate'}]

# %%
for i in remove_button_list:
    buttons.remove(i)
           
    
#     if any( == el[0] for item in buttons):
#         print("s")

# %%
buttons
# Out:
# [{'title': 'Owner', 'payload': 'Owners'},
#  {'title': 'Quit Form', 'payload': '/quit_form'},
#  {'title': 'More', 'payload': 'second list'}]

# %%
n=[]

# %%
value = "StartDatea"

# %%
if any([value == el[0] for el in n]):
    print("a")

# %%
task_name = "Task 64"

# %%
edit_text=""

# %%
for el in n:
    edit_text += f"{el[0]} as '{el[1]}', "

# %%
edit_text
# Out:
# "StartDate as '11/01/2020', TaskPriority as 'High', DueDate as '11/01/2020', TaskName as 'qwe', "

# %%
edit_text= edit_text[:-2]

# %%
t=f"I will update {task_name} {edit_text}. Please select one of the options below."

# %%
t
# Out:
# "I will update Task 64 StartDate as '11/01/2020', TaskPriority as 'High', DueDate as '11/01/2020', TaskName as 'qwe'. Please select one of the options below."

# %%
sql = """SELECT * FROM chat_dummy_main_copy 
                        """
da = pd.read_sql(sql, engine)

# %%
da[da.StartDate>=da.DueDate]
# Out:
# Empty DataFrame
# Columns: [RowID, ParentRowID, TaskID, ParentTaskID, TeamName, TaskName, TaskType, TaskScheduleType, Duration, PlannedStartDate, StartDate, PlannedDueDate, DueDate, Owners, TaskStatus, PercentComplete, TaskPriority, TaskSeverity, NodeLevel, Node, TaskUID, UserId, FullName, Password, First_Name, Last_Name, EffortHours]
# Index: []
#
# [0 rows x 27 columns]

# %%
data.to_excel("dummy_copy.xlsx", index=False)

# %%
import pandas as pd

from sqlalchemy import create_engine

# %%
# Open database connection
engine = create_engine('mysql+mysqlconnector://root:1234@localhost:3306/exercise', echo=False)

# %%
sql = """SELECT * FROM employees """

d = pd.read_sql(sql, engine)
d
# Out:
#    id    name     age
# 0   1     Ali  213123
# 1   2  Behcet      15
# 2   3   Cemal      20

# %%
tup =  'UPDATE employees SET age = "213123" WHERE name = "Ali"'

# %%
conn.execute(tup)

# %%
conn.close()

# %%
connection = engine.raw_connection()
cursor = connection.cursor()

# %%
cursor.execute(tup)

# %%
d = cursor.execute("SELECT * FROM employees")

# %%
d

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-90000d484d65> in <module>
# ----> 1 df_1
#
# NameError: name 'df_1' is not defined

# %%
isinstance(data["StartDate"].iloc[0], datetime)
# Out:
# True

# %%
data["StartDate"].iloc[0].strftime("%b %m %Y")
# Out:
# 'Jun 06 2021'

# %%
data["StartDate"].iloc[0] ==datetime.now().date()
# Out:
# True

# %%
sql = """SELECT * FROM chat_dummy_main_copy"""

data = pd.read_sql(sql, engine)
data
# Out:
#       RowID  ParentRowID  TaskID  ParentTaskID TeamName         TaskName  \
# 0         1          NaN   51541           NaN       HR         Task 651
# 1        15          5.0   51548       51543.0       HR  Summary Task141
# 2        30         15.0   51556       51548.0       IT  Summary Task157
# 3       130        110.0   51590       51580.0       IT     Milestone133
# 4       140        110.0   51595       51580.0       IT         Task 762
# ...     ...          ...     ...           ...      ...              ...
# 1334   1116       1090.0   52821       52808.0       IT         Task 810
# 1335   1150          3.0   52828       52433.0       HR         Task 231
# 1336   1220       1210.0   52853       52848.0       IT          Task135
# 1337   1234       1210.0   52860       52848.0       HR           Task40
# 1338   1266       1210.0   52876       52848.0       HR         Task 133
#
#           TaskType TaskScheduleType  Duration PlannedStartDate  ...  \
# ...

# %%
data[["StartDate", "DueDate"]].head()
# Out:
#    StartDate    DueDate
# 0 2020-12-02 2020-12-16
# 1 2020-08-05 2020-08-19
# 2 2020-08-02 2020-08-16
# 3 2020-08-23 2020-09-06
# 4 2020-08-29 2020-09-12

# %%
TASKFEATURES = ["TaskName", "StartDate", "DueDate", "Owners", "PercentComplete", "TaskPriority", "TaskSeverity", "TaskStatus", "EffortHours"]

# %%
task_name = "Task 64"
sql = """SELECT * FROM chat_dummy_main_copy 
                        WHERE TaskName = '{}' """.format(task_name)

data = pd.read_sql(sql, engine)

# %%
data[TASKFEATURES].iloc[0]
# Out:
# TaskName                       Task 64
# StartDate          2021-01-20 00:00:00
# DueDate            2021-06-21 00:00:00
# Owners                    Keshav Verma
# PercentComplete                     14
# TaskPriority                    Medium
# TaskSeverity                       Low
# TaskStatus                     At Risk
# EffortHours                        136
# Name: 0, dtype: object

# %%
sql_conn = engine.connect()
                
query_text = f""" UPDATE chat_dummy_main_copy SET StartDate = '{e}' WHERE TaskName = "{task_name}" """
        
sql_conn.execute(query_text)
sql_conn.close()

# %%
import sqlalchemy 
sqlalchemy.__version__
# Out:
# '1.3.18'

# %%
type(sql_conn)
# Out:
# sqlalchemy.engine.base.Connection

# %%
status= TASKFEATURES.copy()

# %%
status
# Out:
# ['TaskName',
#  'StartDate',
#  'DueDate',
#  'Owners',
#  'PercentComplete',
#  'TaskPriority',
#  'TaskSeverity',
#  'TaskStatus',
#  'EffortHours']

# %%
status.remove("TaskName")

# %%
TASKFEATURES
# Out:
# ['TaskName',
#  'StartDate',
#  'DueDate',
#  'Owners',
#  'PercentComplete',
#  'TaskPriority',
#  'TaskSeverity',
#  'TaskStatus',
#  'EffortHours']

# %%
sql = """SELECT * FROM task"""

data = pd.read_sql(sql, engine)
data
# Out:
#       RowID  ParentRowID  TaskID  ParentTaskID TeamName         TaskName  \
# 0         1          NaN   51541           NaN       HR         Task 651
# 1        15          5.0   51548       51543.0       HR  Summary Task141
# 2        30         15.0   51556       51548.0       IT  Summary Task157
# 3       130        110.0   51590       51580.0       IT     Milestone133
# 4       140        110.0   51595       51580.0       IT         Task 762
# ...     ...          ...     ...           ...      ...              ...
# 1334   1116       1090.0   52821       52808.0       IT         Task 810
# 1335   1150          3.0   52828       52433.0       HR         Task 231
# 1336   1220       1210.0   52853       52848.0       IT          Task135
# 1337   1234       1210.0   52860       52848.0       HR           Task40
# 1338   1266       1210.0   52876       52848.0       HR         Task 133
#
#           TaskType TaskScheduleType  Duration PlannedStartDate  ... NodeLevel  \
# ...

# %%
sql = """SELECT * FROM chat_dummy_dep"""

data_1 = pd.read_sql(sql, engine)
data_1
# Out:
#               TaskName      DependentOn PlannedStartDate  StartDate  \
# 0            Task 6510         Task 651       2020-05-13 2020-05-13
# 1            Task 6511         Task 651       2020-04-12 2020-04-12
# 2     Summary Task1410  Summary Task141       2020-04-19 2020-04-19
# 3     Summary Task1411  Summary Task141       2020-06-07 2020-06-07
# 4     Summary Task1412  Summary Task141       2020-06-05 2020-06-05
# ...                ...              ...              ...        ...
# 6102          Task4012           Task40       2021-05-12 2021-05-12
# 6103         Task 1330         Task 133       2021-04-23 2021-04-23
# 6104         Task 1331         Task 133       2021-04-08 2021-04-08
# 6105         Task 1332         Task 133       2021-06-16 2021-06-16
# 6106         Task 1333         Task 133       2021-05-27 2021-05-27
#
#         DueDate PlannedDueDate TaskStatus  PercentComplete TaskPriority  \
# 0    2020-05-27     2020-05-27        New               20         High
# ...

# %%
data = pd.merge(data, data_1[["TaskName", "Department"]], on="TaskName", how="left")

# %%
data.loc[data.Department.isnull(), "Department"] ="IT"

# %%
data.isnull().sum()
# Out:
# RowID                 0
# ParentRowID           4
# TaskID                0
# ParentTaskID          4
# TeamName              0
# TaskName              0
# TaskType              0
# TaskScheduleType      0
# Duration            447
# PlannedStartDate      0
# StartDate             0
# PlannedDueDate        0
# DueDate               0
# Owners                0
# TaskStatus            0
# PercentComplete       0
# TaskPriority          0
# TaskSeverity          0
# NodeLevel             0
# Node                  0
# TaskUID               0
# UserId                0
# FullName              0
# Password              0
# First_Name            0
# Last_Name             0
# EffortHours           0
# Department            0
# dtype: int64

# %%
data.Department.unique()
# Out:
# array(['IT', 'HR', 'Finance', 'Operations'], dtype=object)

# %%
data.Owners.unique()
# Out:
# array(['Saresh Gupta', 'George Pushkin', 'Frank Cook', 'Parmesh Khan',
#        'Diana Perez', 'Matthew Reed', 'Keshav Verma', 'Sara Boyd',
#        'Karl Owens', 'Richard McCarter', 'Aahan Sabapathi',
#        'Samir Sljivo', 'Thomas Douglas', 'Varesh Swati'], dtype=object)

# %%
it = ['Saresh Gupta', 'George Pushkin', 'Frank Cook', 'Thomas Douglas', 'Varesh Swati']

# %%
data.loc[data.Owners.isin(it), "Department"]="IT"

# %%
fin = ['Diana Perez', 'Matthew Reed', 'Keshav Verma']
data.loc[data.Owners.isin(fin), "Department"]="Finance"

# %%
hr = ['Parmesh Khan', 'Sara Boyd', 'Karl Owens']
data.loc[data.Owners.isin(hr), "Department"]="HR"

# %%
op = ['Richard McCarter', 'Aahan Sabapathi', 'Samir Sljivo']
data.loc[data.Owners.isin(op), "Department"]="Operations"
